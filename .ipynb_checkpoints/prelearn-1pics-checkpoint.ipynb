# %%
#https://keras.io/examples/rl/deep_q_network_breakout/#train
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
from keras.models import Model, load_model
from keras.models import Sequential
from keras.layers import Input, BatchNormalization, Activation, Dense, Dropout, Flatten, ZeroPadding2D, UpSampling2D
from keras.layers.core import Lambda, RepeatVector, Reshape
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D, GlobalMaxPool2D
from keras.layers.merge import concatenate, add
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.optimizers import SGD, Adam
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.losses import Huber
from keras.regularizers import l2
from keras import initializers
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow import keras
# Out:
# Using TensorFlow backend.

# %%
import os.path
import pandas as pd 
import random
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
dim = (50,50) 
pathname = r"C:\Users\Flo\Studium\Sem5\Bilder"
datadirname = ""
testdirname = "test"
validdirname = "valid"
modeldirname = "model"
datacsvname = "data.csv"
modeljsonname="model.json"
modelweightname="modelundso.h5"


MAXREWARD = 1.0
PENALTY = -1.0
MOVEPENALTY = 0.0

MAXREWARD_OVER =1.0
PENALTY_OVER = -1.0
MOVEPENALTY_OVER = 0.0

MAXREWARD_OVER = 1.0
PENALTY_OVER = -1.0
MOVEPENALTY_OVER = 0.0

DISCOUNT = 0.99


actionstonum = {"RIGHT": 0,
           "LEFT": 1,
           "UP" : 2,
           "DOWN" : 3,
          }
numtoactions = {0: "RIGHT",
           1: "LEFT",
           2: "UP",
           3: "DOWN",
          }

# %%
def create_q_model():
    # Network defined by the Deepmind paper
    inputs = layers.Input(shape=(dim[0], dim[1], 3,))

    # Convolutions on the frames on the screen
    layer1 = layers.Conv2D(32, 8, strides=4, activation="relu")(inputs)
    layer2 = layers.Conv2D(64, 4, strides=2, activation="relu")(layer1)
    layer3 = layers.Conv2D(64, 3, strides=1, activation="relu")(layer2)

    layer4 = layers.Flatten()(layer3)

    layer5 = layers.Dense(512, activation="relu")(layer4)
    action = layers.Dense(4, activation="linear")(layer5)

    return keras.Model(inputs=inputs, outputs=action)

# The first model makes the predictions for Q-values which are used to
# make a action.
model = create_q_model()
# Build a target model for the prediction of future rewards.
# The weights of a target model get updated every 10000 steps thus when the
# loss between the Q-values is calculated the target Q-value is stable.
model_target = create_q_model()
# Out:
# WARNING:tensorflow:From C:\Users\Flo\anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
opt = keras.optimizers.Adam(learning_rate=3.0e-4, clipnorm=1.0)
# or mean_squared_logarithmic_error ?
# or mean_squared_error
model.compile(loss=Huber(),optimizer=opt, metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 50, 50, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 11, 11, 32)        6176
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 4, 4, 64)          32832
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 2, 2, 64)          36928
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               131584
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 209,572
# Trainable params: 209,572
# Non-trainable params: 0
# _________________________________________________________________

# %%
callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.00001, verbose=1),
    ModelCheckpoint(os.path.join(pathname, modeldirname,modelweightname), verbose=1, save_best_only=True, save_weights_only=True)
]

# %%
def load_replay_memory(pathname = pathname, datadirname = datadirname, datacsvname = datacsvname):

    shufflelist = []
    
    assert os.path.isfile(os.path.join(pathname, datadirname,datacsvname)) == True

    f = open(os.path.join(os.path.join(pathname, datadirname,datacsvname)), "r")

    df = pd.read_csv(f, index_col = 0) 

    for index, row in df.iterrows():

        currentpicname = row["currentstate"]
        action = actionstonum[row["action"]]
        reward = row["reward"]
        nextpicname = row["nextstate"]
        terminated = row["terminated"]
        

        assert os.path.isfile(os.path.join(pathname, datadirname,currentpicname)) == True
        assert (action < 5 and action >= 0)
        assert isinstance(reward,int) or isinstance(reward, float)
        assert os.path.isfile(os.path.join(pathname, datadirname,nextpicname)) == True

        
        if reward != PENALTY:
            shufflelist.append([currentpicname,action,reward,nextpicname, terminated])

    random.shuffle(shufflelist)

    f.close()

    return shufflelist

# %%
def generatebatchdata(batchsize):
    shufflelist = []
    shufflelist = load_replay_memory()
    print(f"length of shufflelist is {len(shufflelist)}")

    while True:
        batchstart = 0
        batchend = batchsize    
        
        while batchstart < len(shufflelist):
            
            imagelist = []
            targetlist = []
            
            limit = min(batchend, len(shufflelist))

            for i in range(batchstart, limit):
                filename = os.path.join(pathname, datadirname, shufflelist[i][3])
                imagelist.append(cv2.imread(filename,cv2.IMREAD_COLOR))
                targetlist.append([shufflelist[i][1], shufflelist[i][2], shufflelist[i][3], shufflelist[i][4]])

            
            print('shufflelist' + str(targetlist))
            traindata = np.array(imagelist, dtype=np.float32) / 255.0
            targetlist = np.array(targetlist, dtype=np.float32)
            
            yield (traindata,targetlist)    

            batchstart += batchsize   
            batchend += batchsize

# %%
generator_train = generatebatchdata(20)
#generator_valid = generatebatchdata(2, os.path.join(pathname, validdirname), datacsvname)

# %%
#print(os.path.join(pathname, datadirname,datacsvname))
#os.path.join(pathname, datadirname, datacsvname)

# %%
#model.fit_generator(generator_train,steps_per_epoch=700, epochs=10, callbacks=callbacks, validation_data=generator_valid, validation_steps=150)
model.fit_generator(generator_train, steps_per_epoch=1400, epochs=4)
# Out:
# Epoch 1/4
# length of shufflelist is 356
# shufflelist[['current_1_16.png', 3, 0, 'next_1_16.png', False], ['current_2_3.png', 0, 0, 'next_2_3.png', False], ['current_0_0.png', 0, 0, 'next_0_0.png', False], ['current_5_1.png', 0, 0, 'next_5_1.png', False], ['current_4_59.png', 1, 0, 'next_4_59.png', False], ['current_2_68.png', 2, 0, 'next_2_68.png', False], ['current_1_10.png', 1, 0, 'next_1_10.png', False], ['current_4_10.png', 1, 0, 'next_4_10.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_0_0.png', 0, 0, 'next_0_0.png', False], ['current_2_45.png', 0, 0, 'next_2_45.png', False], ['current_4_12.png', 1, 0, 'next_4_12.png', False], ['current_4_36.png', 3, 0, 'next_4_36.png', False], ['current_1_92.png', 0, 0, 'next_1_92.png', False], ['current_4_1.png', 0, 0, 'next_4_1.png', False], ['current_1_59.png', 3, 0, 'next_1_59.png', False], ['current_7_3.png', 0, 0, 'next_7_3.png', False], ['current_1_34.png', 2, 0, 'next_1_34.png', False], ['current_1_11.png', 1, 0, 'next_1_11.png', False], ['current_1_71.png', 2, 0, 'next_1_71.png', False], ['current_1_0.png', 0, 0, 'next_1_0.png', False], ['current_1_58.png', 3, 10, 'next_1_58.png', False], ['current_1_23.png', 0, 0, 'next_1_23.png', False], ['current_2_1.png', 0, 0, 'next_2_1.png', False], ['current_2_23.png', 0, 0, 'next_2_23.png', False], ['current_7_1.png', 0, 0, 'next_7_1.png', False], ['current_1_64.png', 0, 0, 'next_1_64.png', False], ['current_4_18.png', 2, 0, 'next_4_18.png', False], ['current_4_39.png', 3, 0, 'next_4_39.png', False], ['current_2_67.png', 2, 0, 'next_2_67.png', False], ['current_1_49.png', 3, 0, 'next_1_49.png', False], ['current_2_26.png', 3, 0, 'next_2_26.png', False], ['current_4_6.png', 3, 0, 'next_4_6.png', False], ['current_2_58.png', 3, 0, 'next_2_58.png', False], ['current_4_27.png', 0, 0, 'next_4_27.png', False], ['current_1_63.png', 0, 0, 'next_1_63.png', False], ['current_2_49.png', 1, 10, 'next_2_49.png', False], ['current_2_24.png', 0, 0, 'next_2_24.png', False], ['current_1_60.png', 0, 0, 'next_1_60.png', False], ['current_1_86.png', 1, 0, 'next_1_86.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_6_1.png', 0, 0, 'next_6_1.png', False], ['current_7_2.png', 0, 0, 'next_7_2.png', False], ['current_1_56.png', 3, 0, 'next_1_56.png', False], ['current_3_2.png', 0, 0, 'next_3_2.png', False], ['current_1_47.png', 3, 0, 'next_1_47.png', False], ['current_1_19.png', 3, 0, 'next_1_19.png', False], ['current_4_44.png', 2, 0, 'next_4_44.png', False], ['current_1_20.png', 0, 10, 'next_1_20.png', False], ['current_7_2.png', 0, 0, 'next_7_2.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_2_54.png', 1, 0, 'next_2_54.png', False], ['current_1_74.png', 2, 0, 'next_1_74.png', False], ['current_2_25.png', 3, 0, 'next_2_25.png', False], ['current_2_12.png', 1, 0, 'next_2_12.png', False], ['current_4_53.png', 1, 0, 'next_4_53.png', False], ['current_4_52.png', 2, 0, 'next_4_52.png', False], ['current_4_54.png', 1, 10, 'next_4_54.png', False], ['current_1_13.png', 1, 0, 'next_1_13.png', False], ['current_6_14.png', 1, 0, 'next_6_14.png', False], ['current_4_8.png', 1, 0, 'next_4_8.png', False], ['current_2_34.png', 1, 0, 'next_2_34.png', False], ['current_6_3.png', 0, 0, 'next_6_3.png', False], ['current_2_75.png', 2, 0, 'next_2_75.png', False], ['current_1_48.png', 3, 0, 'next_1_48.png', False], ['current_2_17.png', 2, 0, 'next_2_17.png', False], ['current_4_28.png', 0, 0, 'next_4_28.png', False], ['current_6_19.png', 1, 0, 'next_6_19.png', False], ['current_1_2.png', 0, 0, 'next_1_2.png', False], ['current_4_3.png', 3, 0, 'next_4_3.png', False], ['current_2_63.png', 0, 0, 'next_2_63.png', False], ['current_6_2.png', 0, 0, 'next_6_2.png', False], ['current_1_80.png', 1, 0, 'next_1_80.png', False], ['current_3_1.png', 0, 0, 'next_3_1.png', False], ['current_4_0.png', 0, 0, 'next_4_0.png', False], ['current_2_2.png', 0, 0, 'next_2_2.png', False], ['current_2_60.png', 0, 0, 'next_2_60.png', False], ['current_1_90.png', 0, 0, 'ne ...
# shufflelist[['current_1_16.png', 3, 0, 'next_1_16.png', False], ['current_2_3.png', 0, 0, 'next_2_3.png', False], ['current_0_0.png', 0, 0, 'next_0_0.png', False], ['current_5_1.png', 0, 0, 'next_5_1.png', False], ['current_4_59.png', 1, 0, 'next_4_59.png', False], ['current_2_68.png', 2, 0, 'next_2_68.png', False], ['current_1_10.png', 1, 0, 'next_1_10.png', False], ['current_4_10.png', 1, 0, 'next_4_10.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_0_0.png', 0, 0, 'next_0_0.png', False], ['current_2_45.png', 0, 0, 'next_2_45.png', False], ['current_4_12.png', 1, 0, 'next_4_12.png', False], ['current_4_36.png', 3, 0, 'next_4_36.png', False], ['current_1_92.png', 0, 0, 'next_1_92.png', False], ['current_4_1.png', 0, 0, 'next_4_1.png', False], ['current_1_59.png', 3, 0, 'next_1_59.png', False], ['current_7_3.png', 0, 0, 'next_7_3.png', False], ['current_1_34.png', 2, 0, 'next_1_34.png', False], ['current_1_11.png', 1, 0, 'next_1_11.png', False], ['current_1_71.png', 2, 0, 'next_1_71.png', False], ['current_1_0.png', 0, 0, 'next_1_0.png', False], ['current_1_58.png', 3, 10, 'next_1_58.png', False], ['current_1_23.png', 0, 0, 'next_1_23.png', False], ['current_2_1.png', 0, 0, 'next_2_1.png', False], ['current_2_23.png', 0, 0, 'next_2_23.png', False], ['current_7_1.png', 0, 0, 'next_7_1.png', False], ['current_1_64.png', 0, 0, 'next_1_64.png', False], ['current_4_18.png', 2, 0, 'next_4_18.png', False], ['current_4_39.png', 3, 0, 'next_4_39.png', False], ['current_2_67.png', 2, 0, 'next_2_67.png', False], ['current_1_49.png', 3, 0, 'next_1_49.png', False], ['current_2_26.png', 3, 0, 'next_2_26.png', False], ['current_4_6.png', 3, 0, 'next_4_6.png', False], ['current_2_58.png', 3, 0, 'next_2_58.png', False], ['current_4_27.png', 0, 0, 'next_4_27.png', False], ['current_1_63.png', 0, 0, 'next_1_63.png', False], ['current_2_49.png', 1, 10, 'next_2_49.png', False], ['current_2_24.png', 0, 0, 'next_2_24.png', False], ['current_1_60.png', 0, 0, 'next_1_60.png', False], ['current_1_86.png', 1, 0, 'next_1_86.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_6_1.png', 0, 0, 'next_6_1.png', False], ['current_7_2.png', 0, 0, 'next_7_2.png', False], ['current_1_56.png', 3, 0, 'next_1_56.png', False], ['current_3_2.png', 0, 0, 'next_3_2.png', False], ['current_1_47.png', 3, 0, 'next_1_47.png', False], ['current_1_19.png', 3, 0, 'next_1_19.png', False], ['current_4_44.png', 2, 0, 'next_4_44.png', False], ['current_1_20.png', 0, 10, 'next_1_20.png', False], ['current_7_2.png', 0, 0, 'next_7_2.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_2_54.png', 1, 0, 'next_2_54.png', False], ['current_1_74.png', 2, 0, 'next_1_74.png', False], ['current_2_25.png', 3, 0, 'next_2_25.png', False], ['current_2_12.png', 1, 0, 'next_2_12.png', False], ['current_4_53.png', 1, 0, 'next_4_53.png', False], ['current_4_52.png', 2, 0, 'next_4_52.png', False], ['current_4_54.png', 1, 10, 'next_4_54.png', False], ['current_1_13.png', 1, 0, 'next_1_13.png', False], ['current_6_14.png', 1, 0, 'next_6_14.png', False], ['current_4_8.png', 1, 0, 'next_4_8.png', False], ['current_2_34.png', 1, 0, 'next_2_34.png', False], ['current_6_3.png', 0, 0, 'next_6_3.png', False], ['current_2_75.png', 2, 0, 'next_2_75.png', False], ['current_1_48.png', 3, 0, 'next_1_48.png', False], ['current_2_17.png', 2, 0, 'next_2_17.png', False], ['current_4_28.png', 0, 0, 'next_4_28.png', False], ['current_6_19.png', 1, 0, 'next_6_19.png', False], ['current_1_2.png', 0, 0, 'next_1_2.png', False], ['current_4_3.png', 3, 0, 'next_4_3.png', False], ['current_2_63.png', 0, 0, 'next_2_63.png', False], ['current_6_2.png', 0, 0, 'next_6_2.png', False], ['current_1_80.png', 1, 0, 'next_1_80.png', False], ['current_3_1.png', 0, 0, 'next_3_1.png', False], ['current_4_0.png', 0, 0, 'next_4_0.png', False], ['current_2_2.png', 0, 0, 'next_2_2.png', False], ['current_2_60.png', 0, 0, 'next_2_60.png', False], ['current_1_90.png', 0, 0, 'ne ...
# shufflelist[['current_1_16.png', 3, 0, 'next_1_16.png', False], ['current_2_3.png', 0, 0, 'next_2_3.png', False], ['current_0_0.png', 0, 0, 'next_0_0.png', False], ['current_5_1.png', 0, 0, 'next_5_1.png', False], ['current_4_59.png', 1, 0, 'next_4_59.png', False], ['current_2_68.png', 2, 0, 'next_2_68.png', False], ['current_1_10.png', 1, 0, 'next_1_10.png', False], ['current_4_10.png', 1, 0, 'next_4_10.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_0_0.png', 0, 0, 'next_0_0.png', False], ['current_2_45.png', 0, 0, 'next_2_45.png', False], ['current_4_12.png', 1, 0, 'next_4_12.png', False], ['current_4_36.png', 3, 0, 'next_4_36.png', False], ['current_1_92.png', 0, 0, 'next_1_92.png', False], ['current_4_1.png', 0, 0, 'next_4_1.png', False], ['current_1_59.png', 3, 0, 'next_1_59.png', False], ['current_7_3.png', 0, 0, 'next_7_3.png', False], ['current_1_34.png', 2, 0, 'next_1_34.png', False], ['current_1_11.png', 1, 0, 'next_1_11.png', False], ['current_1_71.png', 2, 0, 'next_1_71.png', False], ['current_1_0.png', 0, 0, 'next_1_0.png', False], ['current_1_58.png', 3, 10, 'next_1_58.png', False], ['current_1_23.png', 0, 0, 'next_1_23.png', False], ['current_2_1.png', 0, 0, 'next_2_1.png', False], ['current_2_23.png', 0, 0, 'next_2_23.png', False], ['current_7_1.png', 0, 0, 'next_7_1.png', False], ['current_1_64.png', 0, 0, 'next_1_64.png', False], ['current_4_18.png', 2, 0, 'next_4_18.png', False], ['current_4_39.png', 3, 0, 'next_4_39.png', False], ['current_2_67.png', 2, 0, 'next_2_67.png', False], ['current_1_49.png', 3, 0, 'next_1_49.png', False], ['current_2_26.png', 3, 0, 'next_2_26.png', False], ['current_4_6.png', 3, 0, 'next_4_6.png', False], ['current_2_58.png', 3, 0, 'next_2_58.png', False], ['current_4_27.png', 0, 0, 'next_4_27.png', False], ['current_1_63.png', 0, 0, 'next_1_63.png', False], ['current_2_49.png', 1, 10, 'next_2_49.png', False], ['current_2_24.png', 0, 0, 'next_2_24.png', False], ['current_1_60.png', 0, 0, 'next_1_60.png', False], ['current_1_86.png', 1, 0, 'next_1_86.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_6_1.png', 0, 0, 'next_6_1.png', False], ['current_7_2.png', 0, 0, 'next_7_2.png', False], ['current_1_56.png', 3, 0, 'next_1_56.png', False], ['current_3_2.png', 0, 0, 'next_3_2.png', False], ['current_1_47.png', 3, 0, 'next_1_47.png', False], ['current_1_19.png', 3, 0, 'next_1_19.png', False], ['current_4_44.png', 2, 0, 'next_4_44.png', False], ['current_1_20.png', 0, 10, 'next_1_20.png', False], ['current_7_2.png', 0, 0, 'next_7_2.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_2_54.png', 1, 0, 'next_2_54.png', False], ['current_1_74.png', 2, 0, 'next_1_74.png', False], ['current_2_25.png', 3, 0, 'next_2_25.png', False], ['current_2_12.png', 1, 0, 'next_2_12.png', False], ['current_4_53.png', 1, 0, 'next_4_53.png', False], ['current_4_52.png', 2, 0, 'next_4_52.png', False], ['current_4_54.png', 1, 10, 'next_4_54.png', False], ['current_1_13.png', 1, 0, 'next_1_13.png', False], ['current_6_14.png', 1, 0, 'next_6_14.png', False], ['current_4_8.png', 1, 0, 'next_4_8.png', False], ['current_2_34.png', 1, 0, 'next_2_34.png', False], ['current_6_3.png', 0, 0, 'next_6_3.png', False], ['current_2_75.png', 2, 0, 'next_2_75.png', False], ['current_1_48.png', 3, 0, 'next_1_48.png', False], ['current_2_17.png', 2, 0, 'next_2_17.png', False], ['current_4_28.png', 0, 0, 'next_4_28.png', False], ['current_6_19.png', 1, 0, 'next_6_19.png', False], ['current_1_2.png', 0, 0, 'next_1_2.png', False], ['current_4_3.png', 3, 0, 'next_4_3.png', False], ['current_2_63.png', 0, 0, 'next_2_63.png', False], ['current_6_2.png', 0, 0, 'next_6_2.png', False], ['current_1_80.png', 1, 0, 'next_1_80.png', False], ['current_3_1.png', 0, 0, 'next_3_1.png', False], ['current_4_0.png', 0, 0, 'next_4_0.png', False], ['current_2_2.png', 0, 0, 'next_2_2.png', False], ['current_2_60.png', 0, 0, 'next_2_60.png', False], ['current_1_90.png', 0, 0, 'ne ...
# shufflelist[['current_1_16.png', 3, 0, 'next_1_16.png', False], ['current_2_3.png', 0, 0, 'next_2_3.png', False], ['current_0_0.png', 0, 0, 'next_0_0.png', False], ['current_5_1.png', 0, 0, 'next_5_1.png', False], ['current_4_59.png', 1, 0, 'next_4_59.png', False], ['current_2_68.png', 2, 0, 'next_2_68.png', False], ['current_1_10.png', 1, 0, 'next_1_10.png', False], ['current_4_10.png', 1, 0, 'next_4_10.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_0_0.png', 0, 0, 'next_0_0.png', False], ['current_2_45.png', 0, 0, 'next_2_45.png', False], ['current_4_12.png', 1, 0, 'next_4_12.png', False], ['current_4_36.png', 3, 0, 'next_4_36.png', False], ['current_1_92.png', 0, 0, 'next_1_92.png', False], ['current_4_1.png', 0, 0, 'next_4_1.png', False], ['current_1_59.png', 3, 0, 'next_1_59.png', False], ['current_7_3.png', 0, 0, 'next_7_3.png', False], ['current_1_34.png', 2, 0, 'next_1_34.png', False], ['current_1_11.png', 1, 0, 'next_1_11.png', False], ['current_1_71.png', 2, 0, 'next_1_71.png', False], ['current_1_0.png', 0, 0, 'next_1_0.png', False], ['current_1_58.png', 3, 10, 'next_1_58.png', False], ['current_1_23.png', 0, 0, 'next_1_23.png', False], ['current_2_1.png', 0, 0, 'next_2_1.png', False], ['current_2_23.png', 0, 0, 'next_2_23.png', False], ['current_7_1.png', 0, 0, 'next_7_1.png', False], ['current_1_64.png', 0, 0, 'next_1_64.png', False], ['current_4_18.png', 2, 0, 'next_4_18.png', False], ['current_4_39.png', 3, 0, 'next_4_39.png', False], ['current_2_67.png', 2, 0, 'next_2_67.png', False], ['current_1_49.png', 3, 0, 'next_1_49.png', False], ['current_2_26.png', 3, 0, 'next_2_26.png', False], ['current_4_6.png', 3, 0, 'next_4_6.png', False], ['current_2_58.png', 3, 0, 'next_2_58.png', False], ['current_4_27.png', 0, 0, 'next_4_27.png', False], ['current_1_63.png', 0, 0, 'next_1_63.png', False], ['current_2_49.png', 1, 10, 'next_2_49.png', False], ['current_2_24.png', 0, 0, 'next_2_24.png', False], ['current_1_60.png', 0, 0, 'next_1_60.png', False], ['current_1_86.png', 1, 0, 'next_1_86.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_6_1.png', 0, 0, 'next_6_1.png', False], ['current_7_2.png', 0, 0, 'next_7_2.png', False], ['current_1_56.png', 3, 0, 'next_1_56.png', False], ['current_3_2.png', 0, 0, 'next_3_2.png', False], ['current_1_47.png', 3, 0, 'next_1_47.png', False], ['current_1_19.png', 3, 0, 'next_1_19.png', False], ['current_4_44.png', 2, 0, 'next_4_44.png', False], ['current_1_20.png', 0, 10, 'next_1_20.png', False], ['current_7_2.png', 0, 0, 'next_7_2.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_2_54.png', 1, 0, 'next_2_54.png', False], ['current_1_74.png', 2, 0, 'next_1_74.png', False], ['current_2_25.png', 3, 0, 'next_2_25.png', False], ['current_2_12.png', 1, 0, 'next_2_12.png', False], ['current_4_53.png', 1, 0, 'next_4_53.png', False], ['current_4_52.png', 2, 0, 'next_4_52.png', False], ['current_4_54.png', 1, 10, 'next_4_54.png', False], ['current_1_13.png', 1, 0, 'next_1_13.png', False], ['current_6_14.png', 1, 0, 'next_6_14.png', False], ['current_4_8.png', 1, 0, 'next_4_8.png', False], ['current_2_34.png', 1, 0, 'next_2_34.png', False], ['current_6_3.png', 0, 0, 'next_6_3.png', False], ['current_2_75.png', 2, 0, 'next_2_75.png', False], ['current_1_48.png', 3, 0, 'next_1_48.png', False], ['current_2_17.png', 2, 0, 'next_2_17.png', False], ['current_4_28.png', 0, 0, 'next_4_28.png', False], ['current_6_19.png', 1, 0, 'next_6_19.png', False], ['current_1_2.png', 0, 0, 'next_1_2.png', False], ['current_4_3.png', 3, 0, 'next_4_3.png', False], ['current_2_63.png', 0, 0, 'next_2_63.png', False], ['current_6_2.png', 0, 0, 'next_6_2.png', False], ['current_1_80.png', 1, 0, 'next_1_80.png', False], ['current_3_1.png', 0, 0, 'next_3_1.png', False], ['current_4_0.png', 0, 0, 'next_4_0.png', False], ['current_2_2.png', 0, 0, 'next_2_2.png', False], ['current_2_60.png', 0, 0, 'next_2_60.png', False], ['current_1_90.png', 0, 0, 'ne ...
# shufflelist[['current_1_16.png', 3, 0, 'next_1_16.png', False], ['current_2_3.png', 0, 0, 'next_2_3.png', False], ['current_0_0.png', 0, 0, 'next_0_0.png', False], ['current_5_1.png', 0, 0, 'next_5_1.png', False], ['current_4_59.png', 1, 0, 'next_4_59.png', False], ['current_2_68.png', 2, 0, 'next_2_68.png', False], ['current_1_10.png', 1, 0, 'next_1_10.png', False], ['current_4_10.png', 1, 0, 'next_4_10.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_0_0.png', 0, 0, 'next_0_0.png', False], ['current_2_45.png', 0, 0, 'next_2_45.png', False], ['current_4_12.png', 1, 0, 'next_4_12.png', False], ['current_4_36.png', 3, 0, 'next_4_36.png', False], ['current_1_92.png', 0, 0, 'next_1_92.png', False], ['current_4_1.png', 0, 0, 'next_4_1.png', False], ['current_1_59.png', 3, 0, 'next_1_59.png', False], ['current_7_3.png', 0, 0, 'next_7_3.png', False], ['current_1_34.png', 2, 0, 'next_1_34.png', False], ['current_1_11.png', 1, 0, 'next_1_11.png', False], ['current_1_71.png', 2, 0, 'next_1_71.png', False], ['current_1_0.png', 0, 0, 'next_1_0.png', False], ['current_1_58.png', 3, 10, 'next_1_58.png', False], ['current_1_23.png', 0, 0, 'next_1_23.png', False], ['current_2_1.png', 0, 0, 'next_2_1.png', False], ['current_2_23.png', 0, 0, 'next_2_23.png', False], ['current_7_1.png', 0, 0, 'next_7_1.png', False], ['current_1_64.png', 0, 0, 'next_1_64.png', False], ['current_4_18.png', 2, 0, 'next_4_18.png', False], ['current_4_39.png', 3, 0, 'next_4_39.png', False], ['current_2_67.png', 2, 0, 'next_2_67.png', False], ['current_1_49.png', 3, 0, 'next_1_49.png', False], ['current_2_26.png', 3, 0, 'next_2_26.png', False], ['current_4_6.png', 3, 0, 'next_4_6.png', False], ['current_2_58.png', 3, 0, 'next_2_58.png', False], ['current_4_27.png', 0, 0, 'next_4_27.png', False], ['current_1_63.png', 0, 0, 'next_1_63.png', False], ['current_2_49.png', 1, 10, 'next_2_49.png', False], ['current_2_24.png', 0, 0, 'next_2_24.png', False], ['current_1_60.png', 0, 0, 'next_1_60.png', False], ['current_1_86.png', 1, 0, 'next_1_86.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_6_1.png', 0, 0, 'next_6_1.png', False], ['current_7_2.png', 0, 0, 'next_7_2.png', False], ['current_1_56.png', 3, 0, 'next_1_56.png', False], ['current_3_2.png', 0, 0, 'next_3_2.png', False], ['current_1_47.png', 3, 0, 'next_1_47.png', False], ['current_1_19.png', 3, 0, 'next_1_19.png', False], ['current_4_44.png', 2, 0, 'next_4_44.png', False], ['current_1_20.png', 0, 10, 'next_1_20.png', False], ['current_7_2.png', 0, 0, 'next_7_2.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_2_54.png', 1, 0, 'next_2_54.png', False], ['current_1_74.png', 2, 0, 'next_1_74.png', False], ['current_2_25.png', 3, 0, 'next_2_25.png', False], ['current_2_12.png', 1, 0, 'next_2_12.png', False], ['current_4_53.png', 1, 0, 'next_4_53.png', False], ['current_4_52.png', 2, 0, 'next_4_52.png', False], ['current_4_54.png', 1, 10, 'next_4_54.png', False], ['current_1_13.png', 1, 0, 'next_1_13.png', False], ['current_6_14.png', 1, 0, 'next_6_14.png', False], ['current_4_8.png', 1, 0, 'next_4_8.png', False], ['current_2_34.png', 1, 0, 'next_2_34.png', False], ['current_6_3.png', 0, 0, 'next_6_3.png', False], ['current_2_75.png', 2, 0, 'next_2_75.png', False], ['current_1_48.png', 3, 0, 'next_1_48.png', False], ['current_2_17.png', 2, 0, 'next_2_17.png', False], ['current_4_28.png', 0, 0, 'next_4_28.png', False], ['current_6_19.png', 1, 0, 'next_6_19.png', False], ['current_1_2.png', 0, 0, 'next_1_2.png', False], ['current_4_3.png', 3, 0, 'next_4_3.png', False], ['current_2_63.png', 0, 0, 'next_2_63.png', False], ['current_6_2.png', 0, 0, 'next_6_2.png', False], ['current_1_80.png', 1, 0, 'next_1_80.png', False], ['current_3_1.png', 0, 0, 'next_3_1.png', False], ['current_4_0.png', 0, 0, 'next_4_0.png', False], ['current_2_2.png', 0, 0, 'next_2_2.png', False], ['current_2_60.png', 0, 0, 'next_2_60.png', False], ['current_1_90.png', 0, 0, 'ne ...
# shufflelist[['current_1_16.png', 3, 0, 'next_1_16.png', False], ['current_2_3.png', 0, 0, 'next_2_3.png', False], ['current_0_0.png', 0, 0, 'next_0_0.png', False], ['current_5_1.png', 0, 0, 'next_5_1.png', False], ['current_4_59.png', 1, 0, 'next_4_59.png', False], ['current_2_68.png', 2, 0, 'next_2_68.png', False], ['current_1_10.png', 1, 0, 'next_1_10.png', False], ['current_4_10.png', 1, 0, 'next_4_10.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_0_0.png', 0, 0, 'next_0_0.png', False], ['current_2_45.png', 0, 0, 'next_2_45.png', False], ['current_4_12.png', 1, 0, 'next_4_12.png', False], ['current_4_36.png', 3, 0, 'next_4_36.png', False], ['current_1_92.png', 0, 0, 'next_1_92.png', False], ['current_4_1.png', 0, 0, 'next_4_1.png', False], ['current_1_59.png', 3, 0, 'next_1_59.png', False], ['current_7_3.png', 0, 0, 'next_7_3.png', False], ['current_1_34.png', 2, 0, 'next_1_34.png', False], ['current_1_11.png', 1, 0, 'next_1_11.png', False], ['current_1_71.png', 2, 0, 'next_1_71.png', False], ['current_1_0.png', 0, 0, 'next_1_0.png', False], ['current_1_58.png', 3, 10, 'next_1_58.png', False], ['current_1_23.png', 0, 0, 'next_1_23.png', False], ['current_2_1.png', 0, 0, 'next_2_1.png', False], ['current_2_23.png', 0, 0, 'next_2_23.png', False], ['current_7_1.png', 0, 0, 'next_7_1.png', False], ['current_1_64.png', 0, 0, 'next_1_64.png', False], ['current_4_18.png', 2, 0, 'next_4_18.png', False], ['current_4_39.png', 3, 0, 'next_4_39.png', False], ['current_2_67.png', 2, 0, 'next_2_67.png', False], ['current_1_49.png', 3, 0, 'next_1_49.png', False], ['current_2_26.png', 3, 0, 'next_2_26.png', False], ['current_4_6.png', 3, 0, 'next_4_6.png', False], ['current_2_58.png', 3, 0, 'next_2_58.png', False], ['current_4_27.png', 0, 0, 'next_4_27.png', False], ['current_1_63.png', 0, 0, 'next_1_63.png', False], ['current_2_49.png', 1, 10, 'next_2_49.png', False], ['current_2_24.png', 0, 0, 'next_2_24.png', False], ['current_1_60.png', 0, 0, 'next_1_60.png', False], ['current_1_86.png', 1, 0, 'next_1_86.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_6_1.png', 0, 0, 'next_6_1.png', False], ['current_7_2.png', 0, 0, 'next_7_2.png', False], ['current_1_56.png', 3, 0, 'next_1_56.png', False], ['current_3_2.png', 0, 0, 'next_3_2.png', False], ['current_1_47.png', 3, 0, 'next_1_47.png', False], ['current_1_19.png', 3, 0, 'next_1_19.png', False], ['current_4_44.png', 2, 0, 'next_4_44.png', False], ['current_1_20.png', 0, 10, 'next_1_20.png', False], ['current_7_2.png', 0, 0, 'next_7_2.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_2_54.png', 1, 0, 'next_2_54.png', False], ['current_1_74.png', 2, 0, 'next_1_74.png', False], ['current_2_25.png', 3, 0, 'next_2_25.png', False], ['current_2_12.png', 1, 0, 'next_2_12.png', False], ['current_4_53.png', 1, 0, 'next_4_53.png', False], ['current_4_52.png', 2, 0, 'next_4_52.png', False], ['current_4_54.png', 1, 10, 'next_4_54.png', False], ['current_1_13.png', 1, 0, 'next_1_13.png', False], ['current_6_14.png', 1, 0, 'next_6_14.png', False], ['current_4_8.png', 1, 0, 'next_4_8.png', False], ['current_2_34.png', 1, 0, 'next_2_34.png', False], ['current_6_3.png', 0, 0, 'next_6_3.png', False], ['current_2_75.png', 2, 0, 'next_2_75.png', False], ['current_1_48.png', 3, 0, 'next_1_48.png', False], ['current_2_17.png', 2, 0, 'next_2_17.png', False], ['current_4_28.png', 0, 0, 'next_4_28.png', False], ['current_6_19.png', 1, 0, 'next_6_19.png', False], ['current_1_2.png', 0, 0, 'next_1_2.png', False], ['current_4_3.png', 3, 0, 'next_4_3.png', False], ['current_2_63.png', 0, 0, 'next_2_63.png', False], ['current_6_2.png', 0, 0, 'next_6_2.png', False], ['current_1_80.png', 1, 0, 'next_1_80.png', False], ['current_3_1.png', 0, 0, 'next_3_1.png', False], ['current_4_0.png', 0, 0, 'next_4_0.png', False], ['current_2_2.png', 0, 0, 'next_2_2.png', False], ['current_2_60.png', 0, 0, 'next_2_60.png', False], ['current_1_90.png', 0, 0, 'ne ...
# shufflelist[['current_1_16.png', 3, 0, 'next_1_16.png', False], ['current_2_3.png', 0, 0, 'next_2_3.png', False], ['current_0_0.png', 0, 0, 'next_0_0.png', False], ['current_5_1.png', 0, 0, 'next_5_1.png', False], ['current_4_59.png', 1, 0, 'next_4_59.png', False], ['current_2_68.png', 2, 0, 'next_2_68.png', False], ['current_1_10.png', 1, 0, 'next_1_10.png', False], ['current_4_10.png', 1, 0, 'next_4_10.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_0_0.png', 0, 0, 'next_0_0.png', False], ['current_2_45.png', 0, 0, 'next_2_45.png', False], ['current_4_12.png', 1, 0, 'next_4_12.png', False], ['current_4_36.png', 3, 0, 'next_4_36.png', False], ['current_1_92.png', 0, 0, 'next_1_92.png', False], ['current_4_1.png', 0, 0, 'next_4_1.png', False], ['current_1_59.png', 3, 0, 'next_1_59.png', False], ['current_7_3.png', 0, 0, 'next_7_3.png', False], ['current_1_34.png', 2, 0, 'next_1_34.png', False], ['current_1_11.png', 1, 0, 'next_1_11.png', False], ['current_1_71.png', 2, 0, 'next_1_71.png', False], ['current_1_0.png', 0, 0, 'next_1_0.png', False], ['current_1_58.png', 3, 10, 'next_1_58.png', False], ['current_1_23.png', 0, 0, 'next_1_23.png', False], ['current_2_1.png', 0, 0, 'next_2_1.png', False], ['current_2_23.png', 0, 0, 'next_2_23.png', False], ['current_7_1.png', 0, 0, 'next_7_1.png', False], ['current_1_64.png', 0, 0, 'next_1_64.png', False], ['current_4_18.png', 2, 0, 'next_4_18.png', False], ['current_4_39.png', 3, 0, 'next_4_39.png', False], ['current_2_67.png', 2, 0, 'next_2_67.png', False], ['current_1_49.png', 3, 0, 'next_1_49.png', False], ['current_2_26.png', 3, 0, 'next_2_26.png', False], ['current_4_6.png', 3, 0, 'next_4_6.png', False], ['current_2_58.png', 3, 0, 'next_2_58.png', False], ['current_4_27.png', 0, 0, 'next_4_27.png', False], ['current_1_63.png', 0, 0, 'next_1_63.png', False], ['current_2_49.png', 1, 10, 'next_2_49.png', False], ['current_2_24.png', 0, 0, 'next_2_24.png', False], ['current_1_60.png', 0, 0, 'next_1_60.png', False], ['current_1_86.png', 1, 0, 'next_1_86.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_6_1.png', 0, 0, 'next_6_1.png', False], ['current_7_2.png', 0, 0, 'next_7_2.png', False], ['current_1_56.png', 3, 0, 'next_1_56.png', False], ['current_3_2.png', 0, 0, 'next_3_2.png', False], ['current_1_47.png', 3, 0, 'next_1_47.png', False], ['current_1_19.png', 3, 0, 'next_1_19.png', False], ['current_4_44.png', 2, 0, 'next_4_44.png', False], ['current_1_20.png', 0, 10, 'next_1_20.png', False], ['current_7_2.png', 0, 0, 'next_7_2.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_2_54.png', 1, 0, 'next_2_54.png', False], ['current_1_74.png', 2, 0, 'next_1_74.png', False], ['current_2_25.png', 3, 0, 'next_2_25.png', False], ['current_2_12.png', 1, 0, 'next_2_12.png', False], ['current_4_53.png', 1, 0, 'next_4_53.png', False], ['current_4_52.png', 2, 0, 'next_4_52.png', False], ['current_4_54.png', 1, 10, 'next_4_54.png', False], ['current_1_13.png', 1, 0, 'next_1_13.png', False], ['current_6_14.png', 1, 0, 'next_6_14.png', False], ['current_4_8.png', 1, 0, 'next_4_8.png', False], ['current_2_34.png', 1, 0, 'next_2_34.png', False], ['current_6_3.png', 0, 0, 'next_6_3.png', False], ['current_2_75.png', 2, 0, 'next_2_75.png', False], ['current_1_48.png', 3, 0, 'next_1_48.png', False], ['current_2_17.png', 2, 0, 'next_2_17.png', False], ['current_4_28.png', 0, 0, 'next_4_28.png', False], ['current_6_19.png', 1, 0, 'next_6_19.png', False], ['current_1_2.png', 0, 0, 'next_1_2.png', False], ['current_4_3.png', 3, 0, 'next_4_3.png', False], ['current_2_63.png', 0, 0, 'next_2_63.png', False], ['current_6_2.png', 0, 0, 'next_6_2.png', False], ['current_1_80.png', 1, 0, 'next_1_80.png', False], ['current_3_1.png', 0, 0, 'next_3_1.png', False], ['current_4_0.png', 0, 0, 'next_4_0.png', False], ['current_2_2.png', 0, 0, 'next_2_2.png', False], ['current_2_60.png', 0, 0, 'next_2_60.png', False], ['current_1_90.png', 0, 0, 'ne ...
# shufflelist[['current_1_16.png', 3, 0, 'next_1_16.png', False], ['current_2_3.png', 0, 0, 'next_2_3.png', False], ['current_0_0.png', 0, 0, 'next_0_0.png', False], ['current_5_1.png', 0, 0, 'next_5_1.png', False], ['current_4_59.png', 1, 0, 'next_4_59.png', False], ['current_2_68.png', 2, 0, 'next_2_68.png', False], ['current_1_10.png', 1, 0, 'next_1_10.png', False], ['current_4_10.png', 1, 0, 'next_4_10.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_0_0.png', 0, 0, 'next_0_0.png', False], ['current_2_45.png', 0, 0, 'next_2_45.png', False], ['current_4_12.png', 1, 0, 'next_4_12.png', False], ['current_4_36.png', 3, 0, 'next_4_36.png', False], ['current_1_92.png', 0, 0, 'next_1_92.png', False], ['current_4_1.png', 0, 0, 'next_4_1.png', False], ['current_1_59.png', 3, 0, 'next_1_59.png', False], ['current_7_3.png', 0, 0, 'next_7_3.png', False], ['current_1_34.png', 2, 0, 'next_1_34.png', False], ['current_1_11.png', 1, 0, 'next_1_11.png', False], ['current_1_71.png', 2, 0, 'next_1_71.png', False], ['current_1_0.png', 0, 0, 'next_1_0.png', False], ['current_1_58.png', 3, 10, 'next_1_58.png', False], ['current_1_23.png', 0, 0, 'next_1_23.png', False], ['current_2_1.png', 0, 0, 'next_2_1.png', False], ['current_2_23.png', 0, 0, 'next_2_23.png', False], ['current_7_1.png', 0, 0, 'next_7_1.png', False], ['current_1_64.png', 0, 0, 'next_1_64.png', False], ['current_4_18.png', 2, 0, 'next_4_18.png', False], ['current_4_39.png', 3, 0, 'next_4_39.png', False], ['current_2_67.png', 2, 0, 'next_2_67.png', False], ['current_1_49.png', 3, 0, 'next_1_49.png', False], ['current_2_26.png', 3, 0, 'next_2_26.png', False], ['current_4_6.png', 3, 0, 'next_4_6.png', False], ['current_2_58.png', 3, 0, 'next_2_58.png', False], ['current_4_27.png', 0, 0, 'next_4_27.png', False], ['current_1_63.png', 0, 0, 'next_1_63.png', False], ['current_2_49.png', 1, 10, 'next_2_49.png', False], ['current_2_24.png', 0, 0, 'next_2_24.png', False], ['current_1_60.png', 0, 0, 'next_1_60.png', False], ['current_1_86.png', 1, 0, 'next_1_86.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_6_1.png', 0, 0, 'next_6_1.png', False], ['current_7_2.png', 0, 0, 'next_7_2.png', False], ['current_1_56.png', 3, 0, 'next_1_56.png', False], ['current_3_2.png', 0, 0, 'next_3_2.png', False], ['current_1_47.png', 3, 0, 'next_1_47.png', False], ['current_1_19.png', 3, 0, 'next_1_19.png', False], ['current_4_44.png', 2, 0, 'next_4_44.png', False], ['current_1_20.png', 0, 10, 'next_1_20.png', False], ['current_7_2.png', 0, 0, 'next_7_2.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_2_54.png', 1, 0, 'next_2_54.png', False], ['current_1_74.png', 2, 0, 'next_1_74.png', False], ['current_2_25.png', 3, 0, 'next_2_25.png', False], ['current_2_12.png', 1, 0, 'next_2_12.png', False], ['current_4_53.png', 1, 0, 'next_4_53.png', False], ['current_4_52.png', 2, 0, 'next_4_52.png', False], ['current_4_54.png', 1, 10, 'next_4_54.png', False], ['current_1_13.png', 1, 0, 'next_1_13.png', False], ['current_6_14.png', 1, 0, 'next_6_14.png', False], ['current_4_8.png', 1, 0, 'next_4_8.png', False], ['current_2_34.png', 1, 0, 'next_2_34.png', False], ['current_6_3.png', 0, 0, 'next_6_3.png', False], ['current_2_75.png', 2, 0, 'next_2_75.png', False], ['current_1_48.png', 3, 0, 'next_1_48.png', False], ['current_2_17.png', 2, 0, 'next_2_17.png', False], ['current_4_28.png', 0, 0, 'next_4_28.png', False], ['current_6_19.png', 1, 0, 'next_6_19.png', False], ['current_1_2.png', 0, 0, 'next_1_2.png', False], ['current_4_3.png', 3, 0, 'next_4_3.png', False], ['current_2_63.png', 0, 0, 'next_2_63.png', False], ['current_6_2.png', 0, 0, 'next_6_2.png', False], ['current_1_80.png', 1, 0, 'next_1_80.png', False], ['current_3_1.png', 0, 0, 'next_3_1.png', False], ['current_4_0.png', 0, 0, 'next_4_0.png', False], ['current_2_2.png', 0, 0, 'next_2_2.png', False], ['current_2_60.png', 0, 0, 'next_2_60.png', False], ['current_1_90.png', 0, 0, 'ne ...
# shufflelist[['current_1_16.png', 3, 0, 'next_1_16.png', False], ['current_2_3.png', 0, 0, 'next_2_3.png', False], ['current_0_0.png', 0, 0, 'next_0_0.png', False], ['current_5_1.png', 0, 0, 'next_5_1.png', False], ['current_4_59.png', 1, 0, 'next_4_59.png', False], ['current_2_68.png', 2, 0, 'next_2_68.png', False], ['current_1_10.png', 1, 0, 'next_1_10.png', False], ['current_4_10.png', 1, 0, 'next_4_10.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_0_0.png', 0, 0, 'next_0_0.png', False], ['current_2_45.png', 0, 0, 'next_2_45.png', False], ['current_4_12.png', 1, 0, 'next_4_12.png', False], ['current_4_36.png', 3, 0, 'next_4_36.png', False], ['current_1_92.png', 0, 0, 'next_1_92.png', False], ['current_4_1.png', 0, 0, 'next_4_1.png', False], ['current_1_59.png', 3, 0, 'next_1_59.png', False], ['current_7_3.png', 0, 0, 'next_7_3.png', False], ['current_1_34.png', 2, 0, 'next_1_34.png', False], ['current_1_11.png', 1, 0, 'next_1_11.png', False], ['current_1_71.png', 2, 0, 'next_1_71.png', False], ['current_1_0.png', 0, 0, 'next_1_0.png', False], ['current_1_58.png', 3, 10, 'next_1_58.png', False], ['current_1_23.png', 0, 0, 'next_1_23.png', False], ['current_2_1.png', 0, 0, 'next_2_1.png', False], ['current_2_23.png', 0, 0, 'next_2_23.png', False], ['current_7_1.png', 0, 0, 'next_7_1.png', False], ['current_1_64.png', 0, 0, 'next_1_64.png', False], ['current_4_18.png', 2, 0, 'next_4_18.png', False], ['current_4_39.png', 3, 0, 'next_4_39.png', False], ['current_2_67.png', 2, 0, 'next_2_67.png', False], ['current_1_49.png', 3, 0, 'next_1_49.png', False], ['current_2_26.png', 3, 0, 'next_2_26.png', False], ['current_4_6.png', 3, 0, 'next_4_6.png', False], ['current_2_58.png', 3, 0, 'next_2_58.png', False], ['current_4_27.png', 0, 0, 'next_4_27.png', False], ['current_1_63.png', 0, 0, 'next_1_63.png', False], ['current_2_49.png', 1, 10, 'next_2_49.png', False], ['current_2_24.png', 0, 0, 'next_2_24.png', False], ['current_1_60.png', 0, 0, 'next_1_60.png', False], ['current_1_86.png', 1, 0, 'next_1_86.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_6_1.png', 0, 0, 'next_6_1.png', False], ['current_7_2.png', 0, 0, 'next_7_2.png', False], ['current_1_56.png', 3, 0, 'next_1_56.png', False], ['current_3_2.png', 0, 0, 'next_3_2.png', False], ['current_1_47.png', 3, 0, 'next_1_47.png', False], ['current_1_19.png', 3, 0, 'next_1_19.png', False], ['current_4_44.png', 2, 0, 'next_4_44.png', False], ['current_1_20.png', 0, 10, 'next_1_20.png', False], ['current_7_2.png', 0, 0, 'next_7_2.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_2_54.png', 1, 0, 'next_2_54.png', False], ['current_1_74.png', 2, 0, 'next_1_74.png', False], ['current_2_25.png', 3, 0, 'next_2_25.png', False], ['current_2_12.png', 1, 0, 'next_2_12.png', False], ['current_4_53.png', 1, 0, 'next_4_53.png', False], ['current_4_52.png', 2, 0, 'next_4_52.png', False], ['current_4_54.png', 1, 10, 'next_4_54.png', False], ['current_1_13.png', 1, 0, 'next_1_13.png', False], ['current_6_14.png', 1, 0, 'next_6_14.png', False], ['current_4_8.png', 1, 0, 'next_4_8.png', False], ['current_2_34.png', 1, 0, 'next_2_34.png', False], ['current_6_3.png', 0, 0, 'next_6_3.png', False], ['current_2_75.png', 2, 0, 'next_2_75.png', False], ['current_1_48.png', 3, 0, 'next_1_48.png', False], ['current_2_17.png', 2, 0, 'next_2_17.png', False], ['current_4_28.png', 0, 0, 'next_4_28.png', False], ['current_6_19.png', 1, 0, 'next_6_19.png', False], ['current_1_2.png', 0, 0, 'next_1_2.png', False], ['current_4_3.png', 3, 0, 'next_4_3.png', False], ['current_2_63.png', 0, 0, 'next_2_63.png', False], ['current_6_2.png', 0, 0, 'next_6_2.png', False], ['current_1_80.png', 1, 0, 'next_1_80.png', False], ['current_3_1.png', 0, 0, 'next_3_1.png', False], ['current_4_0.png', 0, 0, 'next_4_0.png', False], ['current_2_2.png', 0, 0, 'next_2_2.png', False], ['current_2_60.png', 0, 0, 'next_2_60.png', False], ['current_1_90.png', 0, 0, 'ne ...
# shufflelist[['current_1_16.png', 3, 0, 'next_1_16.png', False], ['current_2_3.png', 0, 0, 'next_2_3.png', False], ['current_0_0.png', 0, 0, 'next_0_0.png', False], ['current_5_1.png', 0, 0, 'next_5_1.png', False], ['current_4_59.png', 1, 0, 'next_4_59.png', False], ['current_2_68.png', 2, 0, 'next_2_68.png', False], ['current_1_10.png', 1, 0, 'next_1_10.png', False], ['current_4_10.png', 1, 0, 'next_4_10.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_0_0.png', 0, 0, 'next_0_0.png', False], ['current_2_45.png', 0, 0, 'next_2_45.png', False], ['current_4_12.png', 1, 0, 'next_4_12.png', False], ['current_4_36.png', 3, 0, 'next_4_36.png', False], ['current_1_92.png', 0, 0, 'next_1_92.png', False], ['current_4_1.png', 0, 0, 'next_4_1.png', False], ['current_1_59.png', 3, 0, 'next_1_59.png', False], ['current_7_3.png', 0, 0, 'next_7_3.png', False], ['current_1_34.png', 2, 0, 'next_1_34.png', False], ['current_1_11.png', 1, 0, 'next_1_11.png', False], ['current_1_71.png', 2, 0, 'next_1_71.png', False], ['current_1_0.png', 0, 0, 'next_1_0.png', False], ['current_1_58.png', 3, 10, 'next_1_58.png', False], ['current_1_23.png', 0, 0, 'next_1_23.png', False], ['current_2_1.png', 0, 0, 'next_2_1.png', False], ['current_2_23.png', 0, 0, 'next_2_23.png', False], ['current_7_1.png', 0, 0, 'next_7_1.png', False], ['current_1_64.png', 0, 0, 'next_1_64.png', False], ['current_4_18.png', 2, 0, 'next_4_18.png', False], ['current_4_39.png', 3, 0, 'next_4_39.png', False], ['current_2_67.png', 2, 0, 'next_2_67.png', False], ['current_1_49.png', 3, 0, 'next_1_49.png', False], ['current_2_26.png', 3, 0, 'next_2_26.png', False], ['current_4_6.png', 3, 0, 'next_4_6.png', False], ['current_2_58.png', 3, 0, 'next_2_58.png', False], ['current_4_27.png', 0, 0, 'next_4_27.png', False], ['current_1_63.png', 0, 0, 'next_1_63.png', False], ['current_2_49.png', 1, 10, 'next_2_49.png', False], ['current_2_24.png', 0, 0, 'next_2_24.png', False], ['current_1_60.png', 0, 0, 'next_1_60.png', False], ['current_1_86.png', 1, 0, 'next_1_86.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_6_1.png', 0, 0, 'next_6_1.png', False], ['current_7_2.png', 0, 0, 'next_7_2.png', False], ['current_1_56.png', 3, 0, 'next_1_56.png', False], ['current_3_2.png', 0, 0, 'next_3_2.png', False], ['current_1_47.png', 3, 0, 'next_1_47.png', False], ['current_1_19.png', 3, 0, 'next_1_19.png', False], ['current_4_44.png', 2, 0, 'next_4_44.png', False], ['current_1_20.png', 0, 10, 'next_1_20.png', False], ['current_7_2.png', 0, 0, 'next_7_2.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_2_54.png', 1, 0, 'next_2_54.png', False], ['current_1_74.png', 2, 0, 'next_1_74.png', False], ['current_2_25.png', 3, 0, 'next_2_25.png', False], ['current_2_12.png', 1, 0, 'next_2_12.png', False], ['current_4_53.png', 1, 0, 'next_4_53.png', False], ['current_4_52.png', 2, 0, 'next_4_52.png', False], ['current_4_54.png', 1, 10, 'next_4_54.png', False], ['current_1_13.png', 1, 0, 'next_1_13.png', False], ['current_6_14.png', 1, 0, 'next_6_14.png', False], ['current_4_8.png', 1, 0, 'next_4_8.png', False], ['current_2_34.png', 1, 0, 'next_2_34.png', False], ['current_6_3.png', 0, 0, 'next_6_3.png', False], ['current_2_75.png', 2, 0, 'next_2_75.png', False], ['current_1_48.png', 3, 0, 'next_1_48.png', False], ['current_2_17.png', 2, 0, 'next_2_17.png', False], ['current_4_28.png', 0, 0, 'next_4_28.png', False], ['current_6_19.png', 1, 0, 'next_6_19.png', False], ['current_1_2.png', 0, 0, 'next_1_2.png', False], ['current_4_3.png', 3, 0, 'next_4_3.png', False], ['current_2_63.png', 0, 0, 'next_2_63.png', False], ['current_6_2.png', 0, 0, 'next_6_2.png', False], ['current_1_80.png', 1, 0, 'next_1_80.png', False], ['current_3_1.png', 0, 0, 'next_3_1.png', False], ['current_4_0.png', 0, 0, 'next_4_0.png', False], ['current_2_2.png', 0, 0, 'next_2_2.png', False], ['current_2_60.png', 0, 0, 'next_2_60.png', False], ['current_1_90.png', 0, 0, 'ne ...
# shufflelist[['current_1_16.png', 3, 0, 'next_1_16.png', False], ['current_2_3.png', 0, 0, 'next_2_3.png', False], ['current_0_0.png', 0, 0, 'next_0_0.png', False], ['current_5_1.png', 0, 0, 'next_5_1.png', False], ['current_4_59.png', 1, 0, 'next_4_59.png', False], ['current_2_68.png', 2, 0, 'next_2_68.png', False], ['current_1_10.png', 1, 0, 'next_1_10.png', False], ['current_4_10.png', 1, 0, 'next_4_10.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_0_0.png', 0, 0, 'next_0_0.png', False], ['current_2_45.png', 0, 0, 'next_2_45.png', False], ['current_4_12.png', 1, 0, 'next_4_12.png', False], ['current_4_36.png', 3, 0, 'next_4_36.png', False], ['current_1_92.png', 0, 0, 'next_1_92.png', False], ['current_4_1.png', 0, 0, 'next_4_1.png', False], ['current_1_59.png', 3, 0, 'next_1_59.png', False], ['current_7_3.png', 0, 0, 'next_7_3.png', False], ['current_1_34.png', 2, 0, 'next_1_34.png', False], ['current_1_11.png', 1, 0, 'next_1_11.png', False], ['current_1_71.png', 2, 0, 'next_1_71.png', False], ['current_1_0.png', 0, 0, 'next_1_0.png', False], ['current_1_58.png', 3, 10, 'next_1_58.png', False], ['current_1_23.png', 0, 0, 'next_1_23.png', False], ['current_2_1.png', 0, 0, 'next_2_1.png', False], ['current_2_23.png', 0, 0, 'next_2_23.png', False], ['current_7_1.png', 0, 0, 'next_7_1.png', False], ['current_1_64.png', 0, 0, 'next_1_64.png', False], ['current_4_18.png', 2, 0, 'next_4_18.png', False], ['current_4_39.png', 3, 0, 'next_4_39.png', False], ['current_2_67.png', 2, 0, 'next_2_67.png', False], ['current_1_49.png', 3, 0, 'next_1_49.png', False], ['current_2_26.png', 3, 0, 'next_2_26.png', False], ['current_4_6.png', 3, 0, 'next_4_6.png', False], ['current_2_58.png', 3, 0, 'next_2_58.png', False], ['current_4_27.png', 0, 0, 'next_4_27.png', False], ['current_1_63.png', 0, 0, 'next_1_63.png', False], ['current_2_49.png', 1, 10, 'next_2_49.png', False], ['current_2_24.png', 0, 0, 'next_2_24.png', False], ['current_1_60.png', 0, 0, 'next_1_60.png', False], ['current_1_86.png', 1, 0, 'next_1_86.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_6_1.png', 0, 0, 'next_6_1.png', False], ['current_7_2.png', 0, 0, 'next_7_2.png', False], ['current_1_56.png', 3, 0, 'next_1_56.png', False], ['current_3_2.png', 0, 0, 'next_3_2.png', False], ['current_1_47.png', 3, 0, 'next_1_47.png', False], ['current_1_19.png', 3, 0, 'next_1_19.png', False], ['current_4_44.png', 2, 0, 'next_4_44.png', False], ['current_1_20.png', 0, 10, 'next_1_20.png', False], ['current_7_2.png', 0, 0, 'next_7_2.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_2_54.png', 1, 0, 'next_2_54.png', False], ['current_1_74.png', 2, 0, 'next_1_74.png', False], ['current_2_25.png', 3, 0, 'next_2_25.png', False], ['current_2_12.png', 1, 0, 'next_2_12.png', False], ['current_4_53.png', 1, 0, 'next_4_53.png', False], ['current_4_52.png', 2, 0, 'next_4_52.png', False], ['current_4_54.png', 1, 10, 'next_4_54.png', False], ['current_1_13.png', 1, 0, 'next_1_13.png', False], ['current_6_14.png', 1, 0, 'next_6_14.png', False], ['current_4_8.png', 1, 0, 'next_4_8.png', False], ['current_2_34.png', 1, 0, 'next_2_34.png', False], ['current_6_3.png', 0, 0, 'next_6_3.png', False], ['current_2_75.png', 2, 0, 'next_2_75.png', False], ['current_1_48.png', 3, 0, 'next_1_48.png', False], ['current_2_17.png', 2, 0, 'next_2_17.png', False], ['current_4_28.png', 0, 0, 'next_4_28.png', False], ['current_6_19.png', 1, 0, 'next_6_19.png', False], ['current_1_2.png', 0, 0, 'next_1_2.png', False], ['current_4_3.png', 3, 0, 'next_4_3.png', False], ['current_2_63.png', 0, 0, 'next_2_63.png', False], ['current_6_2.png', 0, 0, 'next_6_2.png', False], ['current_1_80.png', 1, 0, 'next_1_80.png', False], ['current_3_1.png', 0, 0, 'next_3_1.png', False], ['current_4_0.png', 0, 0, 'next_4_0.png', False], ['current_2_2.png', 0, 0, 'next_2_2.png', False], ['current_2_60.png', 0, 0, 'next_2_60.png', False], ['current_1_90.png', 0, 0, 'ne ...
# ...
# shufflelist[['current_1_16.png', 3, 0, 'next_1_16.png', False], ['current_2_3.png', 0, 0, 'next_2_3.png', False], ['current_0_0.png', 0, 0, 'next_0_0.png', False], ['current_5_1.png', 0, 0, 'next_5_1.png', False], ['current_4_59.png', 1, 0, 'next_4_59.png', False], ['current_2_68.png', 2, 0, 'next_2_68.png', False], ['current_1_10.png', 1, 0, 'next_1_10.png', False], ['current_4_10.png', 1, 0, 'next_4_10.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_0_0.png', 0, 0, 'next_0_0.png', False], ['current_2_45.png', 0, 0, 'next_2_45.png', False], ['current_4_12.png', 1, 0, 'next_4_12.png', False], ['current_4_36.png', 3, 0, 'next_4_36.png', False], ['current_1_92.png', 0, 0, 'next_1_92.png', False], ['current_4_1.png', 0, 0, 'next_4_1.png', False], ['current_1_59.png', 3, 0, 'next_1_59.png', False], ['current_7_3.png', 0, 0, 'next_7_3.png', False], ['current_1_34.png', 2, 0, 'next_1_34.png', False], ['current_1_11.png', 1, 0, 'next_1_11.png', False], ['current_1_71.png', 2, 0, 'next_1_71.png', False], ['current_1_0.png', 0, 0, 'next_1_0.png', False], ['current_1_58.png', 3, 10, 'next_1_58.png', False], ['current_1_23.png', 0, 0, 'next_1_23.png', False], ['current_2_1.png', 0, 0, 'next_2_1.png', False], ['current_2_23.png', 0, 0, 'next_2_23.png', False], ['current_7_1.png', 0, 0, 'next_7_1.png', False], ['current_1_64.png', 0, 0, 'next_1_64.png', False], ['current_4_18.png', 2, 0, 'next_4_18.png', False], ['current_4_39.png', 3, 0, 'next_4_39.png', False], ['current_2_67.png', 2, 0, 'next_2_67.png', False], ['current_1_49.png', 3, 0, 'next_1_49.png', False], ['current_2_26.png', 3, 0, 'next_2_26.png', False], ['current_4_6.png', 3, 0, 'next_4_6.png', False], ['current_2_58.png', 3, 0, 'next_2_58.png', False], ['current_4_27.png', 0, 0, 'next_4_27.png', False], ['current_1_63.png', 0, 0, 'next_1_63.png', False], ['current_2_49.png', 1, 10, 'next_2_49.png', False], ['current_2_24.png', 0, 0, 'next_2_24.png', False], ['current_1_60.png', 0, 0, 'next_1_60.png', False], ['current_1_86.png', 1, 0, 'next_1_86.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_6_1.png', 0, 0, 'next_6_1.png', False], ['current_7_2.png', 0, 0, 'next_7_2.png', False], ['current_1_56.png', 3, 0, 'next_1_56.png', False], ['current_3_2.png', 0, 0, 'next_3_2.png', False], ['current_1_47.png', 3, 0, 'next_1_47.png', False], ['current_1_19.png', 3, 0, 'next_1_19.png', False], ['current_4_44.png', 2, 0, 'next_4_44.png', False], ['current_1_20.png', 0, 10, 'next_1_20.png', False], ['current_7_2.png', 0, 0, 'next_7_2.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_2_54.png', 1, 0, 'next_2_54.png', False], ['current_1_74.png', 2, 0, 'next_1_74.png', False], ['current_2_25.png', 3, 0, 'next_2_25.png', False], ['current_2_12.png', 1, 0, 'next_2_12.png', False], ['current_4_53.png', 1, 0, 'next_4_53.png', False], ['current_4_52.png', 2, 0, 'next_4_52.png', False], ['current_4_54.png', 1, 10, 'next_4_54.png', False], ['current_1_13.png', 1, 0, 'next_1_13.png', False], ['current_6_14.png', 1, 0, 'next_6_14.png', False], ['current_4_8.png', 1, 0, 'next_4_8.png', False], ['current_2_34.png', 1, 0, 'next_2_34.png', False], ['current_6_3.png', 0, 0, 'next_6_3.png', False], ['current_2_75.png', 2, 0, 'next_2_75.png', False], ['current_1_48.png', 3, 0, 'next_1_48.png', False], ['current_2_17.png', 2, 0, 'next_2_17.png', False], ['current_4_28.png', 0, 0, 'next_4_28.png', False], ['current_6_19.png', 1, 0, 'next_6_19.png', False], ['current_1_2.png', 0, 0, 'next_1_2.png', False], ['current_4_3.png', 3, 0, 'next_4_3.png', False], ['current_2_63.png', 0, 0, 'next_2_63.png', False], ['current_6_2.png', 0, 0, 'next_6_2.png', False], ['current_1_80.png', 1, 0, 'next_1_80.png', False], ['current_3_1.png', 0, 0, 'next_3_1.png', False], ['current_4_0.png', 0, 0, 'next_4_0.png', False], ['current_2_2.png', 0, 0, 'next_2_2.png', False], ['current_2_60.png', 0, 0, 'next_2_60.png', False], ['current_1_90.png', 0, 0, 'ne ...
# shufflelist[['current_1_16.png', 3, 0, 'next_1_16.png', False], ['current_2_3.png', 0, 0, 'next_2_3.png', False], ['current_0_0.png', 0, 0, 'next_0_0.png', False], ['current_5_1.png', 0, 0, 'next_5_1.png', False], ['current_4_59.png', 1, 0, 'next_4_59.png', False], ['current_2_68.png', 2, 0, 'next_2_68.png', False], ['current_1_10.png', 1, 0, 'next_1_10.png', False], ['current_4_10.png', 1, 0, 'next_4_10.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_0_0.png', 0, 0, 'next_0_0.png', False], ['current_2_45.png', 0, 0, 'next_2_45.png', False], ['current_4_12.png', 1, 0, 'next_4_12.png', False], ['current_4_36.png', 3, 0, 'next_4_36.png', False], ['current_1_92.png', 0, 0, 'next_1_92.png', False], ['current_4_1.png', 0, 0, 'next_4_1.png', False], ['current_1_59.png', 3, 0, 'next_1_59.png', False], ['current_7_3.png', 0, 0, 'next_7_3.png', False], ['current_1_34.png', 2, 0, 'next_1_34.png', False], ['current_1_11.png', 1, 0, 'next_1_11.png', False], ['current_1_71.png', 2, 0, 'next_1_71.png', False], ['current_1_0.png', 0, 0, 'next_1_0.png', False], ['current_1_58.png', 3, 10, 'next_1_58.png', False], ['current_1_23.png', 0, 0, 'next_1_23.png', False], ['current_2_1.png', 0, 0, 'next_2_1.png', False], ['current_2_23.png', 0, 0, 'next_2_23.png', False], ['current_7_1.png', 0, 0, 'next_7_1.png', False], ['current_1_64.png', 0, 0, 'next_1_64.png', False], ['current_4_18.png', 2, 0, 'next_4_18.png', False], ['current_4_39.png', 3, 0, 'next_4_39.png', False], ['current_2_67.png', 2, 0, 'next_2_67.png', False], ['current_1_49.png', 3, 0, 'next_1_49.png', False], ['current_2_26.png', 3, 0, 'next_2_26.png', False], ['current_4_6.png', 3, 0, 'next_4_6.png', False], ['current_2_58.png', 3, 0, 'next_2_58.png', False], ['current_4_27.png', 0, 0, 'next_4_27.png', False], ['current_1_63.png', 0, 0, 'next_1_63.png', False], ['current_2_49.png', 1, 10, 'next_2_49.png', False], ['current_2_24.png', 0, 0, 'next_2_24.png', False], ['current_1_60.png', 0, 0, 'next_1_60.png', False], ['current_1_86.png', 1, 0, 'next_1_86.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_6_1.png', 0, 0, 'next_6_1.png', False], ['current_7_2.png', 0, 0, 'next_7_2.png', False], ['current_1_56.png', 3, 0, 'next_1_56.png', False], ['current_3_2.png', 0, 0, 'next_3_2.png', False], ['current_1_47.png', 3, 0, 'next_1_47.png', False], ['current_1_19.png', 3, 0, 'next_1_19.png', False], ['current_4_44.png', 2, 0, 'next_4_44.png', False], ['current_1_20.png', 0, 10, 'next_1_20.png', False], ['current_7_2.png', 0, 0, 'next_7_2.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_2_54.png', 1, 0, 'next_2_54.png', False], ['current_1_74.png', 2, 0, 'next_1_74.png', False], ['current_2_25.png', 3, 0, 'next_2_25.png', False], ['current_2_12.png', 1, 0, 'next_2_12.png', False], ['current_4_53.png', 1, 0, 'next_4_53.png', False], ['current_4_52.png', 2, 0, 'next_4_52.png', False], ['current_4_54.png', 1, 10, 'next_4_54.png', False], ['current_1_13.png', 1, 0, 'next_1_13.png', False], ['current_6_14.png', 1, 0, 'next_6_14.png', False], ['current_4_8.png', 1, 0, 'next_4_8.png', False], ['current_2_34.png', 1, 0, 'next_2_34.png', False], ['current_6_3.png', 0, 0, 'next_6_3.png', False], ['current_2_75.png', 2, 0, 'next_2_75.png', False], ['current_1_48.png', 3, 0, 'next_1_48.png', False], ['current_2_17.png', 2, 0, 'next_2_17.png', False], ['current_4_28.png', 0, 0, 'next_4_28.png', False], ['current_6_19.png', 1, 0, 'next_6_19.png', False], ['current_1_2.png', 0, 0, 'next_1_2.png', False], ['current_4_3.png', 3, 0, 'next_4_3.png', False], ['current_2_63.png', 0, 0, 'next_2_63.png', False], ['current_6_2.png', 0, 0, 'next_6_2.png', False], ['current_1_80.png', 1, 0, 'next_1_80.png', False], ['current_3_1.png', 0, 0, 'next_3_1.png', False], ['current_4_0.png', 0, 0, 'next_4_0.png', False], ['current_2_2.png', 0, 0, 'next_2_2.png', False], ['current_2_60.png', 0, 0, 'next_2_60.png', False], ['current_1_90.png', 0, 0, 'ne ...
# shufflelist[['current_1_16.png', 3, 0, 'next_1_16.png', False], ['current_2_3.png', 0, 0, 'next_2_3.png', False], ['current_0_0.png', 0, 0, 'next_0_0.png', False], ['current_5_1.png', 0, 0, 'next_5_1.png', False], ['current_4_59.png', 1, 0, 'next_4_59.png', False], ['current_2_68.png', 2, 0, 'next_2_68.png', False], ['current_1_10.png', 1, 0, 'next_1_10.png', False], ['current_4_10.png', 1, 0, 'next_4_10.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_0_0.png', 0, 0, 'next_0_0.png', False], ['current_2_45.png', 0, 0, 'next_2_45.png', False], ['current_4_12.png', 1, 0, 'next_4_12.png', False], ['current_4_36.png', 3, 0, 'next_4_36.png', False], ['current_1_92.png', 0, 0, 'next_1_92.png', False], ['current_4_1.png', 0, 0, 'next_4_1.png', False], ['current_1_59.png', 3, 0, 'next_1_59.png', False], ['current_7_3.png', 0, 0, 'next_7_3.png', False], ['current_1_34.png', 2, 0, 'next_1_34.png', False], ['current_1_11.png', 1, 0, 'next_1_11.png', False], ['current_1_71.png', 2, 0, 'next_1_71.png', False], ['current_1_0.png', 0, 0, 'next_1_0.png', False], ['current_1_58.png', 3, 10, 'next_1_58.png', False], ['current_1_23.png', 0, 0, 'next_1_23.png', False], ['current_2_1.png', 0, 0, 'next_2_1.png', False], ['current_2_23.png', 0, 0, 'next_2_23.png', False], ['current_7_1.png', 0, 0, 'next_7_1.png', False], ['current_1_64.png', 0, 0, 'next_1_64.png', False], ['current_4_18.png', 2, 0, 'next_4_18.png', False], ['current_4_39.png', 3, 0, 'next_4_39.png', False], ['current_2_67.png', 2, 0, 'next_2_67.png', False], ['current_1_49.png', 3, 0, 'next_1_49.png', False], ['current_2_26.png', 3, 0, 'next_2_26.png', False], ['current_4_6.png', 3, 0, 'next_4_6.png', False], ['current_2_58.png', 3, 0, 'next_2_58.png', False], ['current_4_27.png', 0, 0, 'next_4_27.png', False], ['current_1_63.png', 0, 0, 'next_1_63.png', False], ['current_2_49.png', 1, 10, 'next_2_49.png', False], ['current_2_24.png', 0, 0, 'next_2_24.png', False], ['current_1_60.png', 0, 0, 'next_1_60.png', False], ['current_1_86.png', 1, 0, 'next_1_86.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_6_1.png', 0, 0, 'next_6_1.png', False], ['current_7_2.png', 0, 0, 'next_7_2.png', False], ['current_1_56.png', 3, 0, 'next_1_56.png', False], ['current_3_2.png', 0, 0, 'next_3_2.png', False], ['current_1_47.png', 3, 0, 'next_1_47.png', False], ['current_1_19.png', 3, 0, 'next_1_19.png', False], ['current_4_44.png', 2, 0, 'next_4_44.png', False], ['current_1_20.png', 0, 10, 'next_1_20.png', False], ['current_7_2.png', 0, 0, 'next_7_2.png', False], ['current_1_1.png', 0, 0, 'next_1_1.png', False], ['current_2_54.png', 1, 0, 'next_2_54.png', False], ['current_1_74.png', 2, 0, 'next_1_74.png', False], ['current_2_25.png', 3, 0, 'next_2_25.png', False], ['current_2_12.png', 1, 0, 'next_2_12.png', False], ['current_4_53.png', 1, 0, 'next_4_53.png', False], ['current_4_52.png', 2, 0, 'next_4_52.png', False], ['current_4_54.png', 1, 10, 'next_4_54.png', False], ['current_1_13.png', 1, 0, 'next_1_13.png', False], ['current_6_14.png', 1, 0, 'next_6_14.png', False], ['current_4_8.png', 1, 0, 'next_4_8.png', False], ['current_2_34.png', 1, 0, 'next_2_34.png', False], ['current_6_3.png', 0, 0, 'next_6_3.png', False], ['current_2_75.png', 2, 0, 'next_2_75.png', False], ['current_1_48.png', 3, 0, 'next_1_48.png', False], ['current_2_17.png', 2, 0, 'next_2_17.png', False], ['current_4_28.png', 0, 0, 'next_4_28.png', False], ['current_6_19.png', 1, 0, 'next_6_19.png', False], ['current_1_2.png', 0, 0, 'next_1_2.png', False], ['current_4_3.png', 3, 0, 'next_4_3.png', False], ['current_2_63.png', 0, 0, 'next_2_63.png', False], ['current_6_2.png', 0, 0, 'next_6_2.png', False], ['current_1_80.png', 1, 0, 'next_1_80.png', False], ['current_3_1.png', 0, 0, 'next_3_1.png', False], ['current_4_0.png', 0, 0, 'next_4_0.png', False], ['current_2_2.png', 0, 0, 'next_2_2.png', False], ['current_2_60.png', 0, 0, 'next_2_60.png', False], ['current_1_90.png', 0, 0, 'ne ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-e44e1307fa81> in <module>
#       1 #model.fit_generator(generator_train,steps_per_epoch=700, epochs=10, callbacks=callbacks, validation_data=generator_valid, validation_steps=150)
# ----> 2 model.fit_generator(generator_train, steps_per_epoch=1400, epochs=4)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1431         shuffle=shuffle,
#    1432         initial_epoch=initial_epoch,
# -> 1433         steps_name='steps_per_epoch')
#    1434
#    1435   def evaluate_generator(self,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_generator.py in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, steps_name, **kwargs)
#     218     step = 0
#     219     while step < target_steps:
# --> 220       batch_data = _get_next_batch(generator, mode)
#     221       if batch_data is None:
#     222         if is_dataset:
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_generator.py in _get_next_batch(generator, mode)
#     360   """Retrieves the next batch of input data."""
#     361   try:
# --> 362     generator_output = next(generator)
#     363   except (StopIteration, errors.OutOfRangeError):
#     364     return None
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\utils\data_utils.py in get(self)
#     916             'Keras requires a thread-safe generator when '
#     917             '`use_multiprocessing=False, workers > 1`. ')
# --> 918       six.reraise(*sys.exc_info())
#
# ~\anaconda3\lib\site-packages\six.py in reraise(tp, value, tb)
#     701             if value.__traceback__ is not tb:
#     702                 raise value.with_traceback(tb)
# --> 703             raise value
#     704         finally:
#     705             value = None
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\utils\data_utils.py in get(self)
#     892     try:
#     893       while self.is_running():
# --> 894         inputs = self.queue.get(block=True).get()
#     895         self.queue.task_done()
#     896         if inputs is not None:
#
# ~\anaconda3\lib\multiprocessing\pool.py in get(self, timeout)
#     655             return self._value
#     656         else:
# --> 657             raise self._value
#     658
#     659     def _set(self, i, obj):
#
# ~\anaconda3\lib\multiprocessing\pool.py in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     119         job, i, func, args, kwds = task
#     120         try:
# --> 121             result = (True, func(*args, **kwds))
#     122         except Exception as e:
#     123             if wrap_exception and func is not _helper_reraises_exception:
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\utils\data_utils.py in next_sample(uid)
#     826       The next value of generator `uid`.
#     827   """
# --> 828   return six.next(_SHARED_SEQUENCES[uid])
#     829
#     830
#
# <ipython-input-51-f9f5f66fd389> in generatebatchdata(batchsize)
#      23
#      24             traindata = np.array(imagelist, dtype=np.float32) / 255.0
# ---> 25             targetlist = np.array(targetlist, dtype=np.float32)
#      26
#      27             yield (traindata,targetlist)
#
# ValueError: could not convert string to float: 'next_1_16.png'

# %%
model_json = model.to_json()
with open(os.path.join(pathname, modeldirname,modeljsonname), "w") as json_file:
    json_file.write(model_json)

model.save_weights(os.path.join(pathname, modeldirname,modelweightname))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-202374b9fe24> in <module>
#       1 model_json = model.to_json()
# ----> 2 with open(os.path.join(pathname, modeldirname,modeljsonname), "w") as json_file:
#       3     json_file.write(model_json)
#       4
#       5 model.save_weights(os.path.join(pathname, modeldirname,modelweightname))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\User\\Documents\\DeepLearning\\Reinforcement\\model\\model-regr.json'

# %%
model.load_weights(os.path.join(pathname, modeldirname,modelweightname))
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 128, 128, 3)       0
# _________________________________________________________________
# zero_padding2d_1 (ZeroPaddin (None, 130, 130, 3)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 64)      1792
# _________________________________________________________________
# activation_1 (Activation)    (None, 128, 128, 64)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64, 64, 64)        0
# _________________________________________________________________
# zero_padding2d_2 (ZeroPaddin (None, 66, 66, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 128)       73856
# _________________________________________________________________
# activation_2 (Activation)    (None, 64, 64, 128)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32, 32, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 131072)            0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               33554688
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 1028
# _________________________________________________________________
# activation_3 (Activation)    (None, 4)                 0
# =================================================================
# Total params: 33,631,364
# Trainable params: 33,631,364
# Non-trainable params: 0
# _________________________________________________________________

# %%
imagetestlist = []

imagetestnames = os.listdir(os.path.join(pathname, testdirname))
imagetestnames.sort()

for imagename in imagetestnames:
    if imagename.endswith(".png"):
        imagetestlist.append(cv2.imread(os.path.join(pathname, testdirname, imagename),cv2.IMREAD_COLOR ))
        
imagetestlist = np.array(imagetestlist, dtype=np.float32)/255.0

print(imagetestlist[0].shape)
# Out:
# (50, 50, 3)

# %%
#testlist = []
#testlist =  load_replay_memory(pathname, testdirname, datacsvname)
#len(testlist)
# Out:
# 261

# %%
#imagetestlist = []
#imagetestdata = []
#for item, (cs, a, rw, fs, term, px, py, fx, fy) in enumerate(testlist):

# %%
predictionslist = model.predict(imagetestlist, batch_size=1, verbose=1)
# Out:
# 532/1 [========================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
imagetestlist = np.array(imagetestlist, dtype=np.int)
imagetestlist = imagetestlist*255

# %%
#'def showpic(i):
ind = 99


print(predictionslist[ind]//4)



new = cv2.circle(imagetestlist[ind], (int(predictionslist[ind][0]//4), int(predictionslist[ind][1]//4)), 1, (100,0,100), 1)
new = cv2.circle(new, (int(predictionslist[ind][2]//4), int(predictionslist[ind][3]//4)), 1, (100,100,100), 1)

plt.imshow(new)
# Out:
# [23. 41. 33. 27.]

# %%
s = "current_1_2.png"
print(str.split(s))
# Out:
# ['current_1_2.png']

# %%
[int(s) for s in str.split(s) if s.isdigit()]
# Out:
# []

# %%
import re
s = re.findall(r'\d+', 'current_145_2.png')[0]
print(s)
# Out:
# current_145
